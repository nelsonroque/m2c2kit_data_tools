# %%
import requests
import pandas as pd
import json
import uuid
import time
import glob
import ipywidgets as widgets

# %% [markdown]
# ## Custom functions

# %%
def extract_all_trials(records, format="pandas"):
  # stack all trials for all records
  all_trials = []
  for cur_record in range(0,len(records)):
    trial_content = json.loads(records[cur_record]['content'])
    trial_data = trial_content.get('trials',[])
    all_trials.extend(trial_data)

  if format == "pandas":
    # create pandas dataframe from all trials
    all_trials_df = pd.DataFrame(all_trials)
    return all_trials_df
  else:
    return all_trials

# %%
def extract_all_otherstuff(records, format="pandas"):
  # stack all trials for all records
  all_trials = []
  for cur_record in range(0,len(records)):
    trial_content = json.loads(records[cur_record]['content'])
    trial_data = trial_content.get('trials',[])
    all_trials.extend(trial_data)

  if format == "pandas":
    # create pandas dataframe from all trials
    all_trials_df = pd.DataFrame(all_trials)
    return all_trials_df
  else:
    return all_trials

# %% [markdown]
# ## Run Job

# %%
def summary_symbol_search(x, trials_expected=20):
    d = {}
    d['flag_is_invalid_n_trials'] = x['session_uuid'].count() != trials_expected
    d['n_trials'] = x['session_uuid'].count()
    d['n_trials_lure'] = (x['trial_type'] == "lure").sum()
    d['n_trials_responsetime_lt250ms'] = (
        x['response_time_duration_ms'] < 250).sum()
    d['n_trials_responsetime_gt10000ms'] = (
        x['response_time_duration_ms'] > 10000).sum()
    d['n_correct_trials'] = (x['user_response_index']
                             == x['correct_response_index']).sum()
    d['n_incorrect_trials'] = (x['user_response_index']
                             != x['correct_response_index']).sum()
    d['mean_response_time_overall'] = x['response_time_duration_ms'].mean()
    d['mean_response_time_correct'] = x.loc[(x['user_response_index']
                                             == x['correct_response_index']), 'response_time_duration_ms'].mean()
    d['mean_response_time_incorrect'] = x.loc[(x['user_response_index']
                                               != x['correct_response_index']), 'response_time_duration_ms'].mean()
    d['median_response_time_overall'] = x['response_time_duration_ms'].median()
    d['median_response_time_correct'] = x.loc[(x['user_response_index']
                                               == x['correct_response_index']), 'response_time_duration_ms'].median()
    d['median_response_time_incorrect'] = x.loc[(x['user_response_index']
                                                 != x['correct_response_index']), 'response_time_duration_ms'].median()
    d['sd_response_time_overall'] = x['response_time_duration_ms'].std()
    d['sd_response_time_correct'] = x.loc[(x['user_response_index']
                                           == x['correct_response_index']), 'response_time_duration_ms'].std()
    d['sd_response_time_incorrect'] = x.loc[(x['user_response_index']
                                             != x['correct_response_index']), 'response_time_duration_ms'].std()
    return pd.Series(d,
                     index=['flag_is_invalid_n_trials',
                            # 'flag_is_potentially_invalid_rt',
                            'n_trials',
                            'n_trials_lure',
                            'n_correct_trials',
                            'n_incorrect_trials',
                            'n_trials_responsetime_lt250ms',
                            'n_trials_responsetime_gt10000ms',
                            'mean_response_time_overall',
                            'mean_response_time_correct',
                            'mean_response_time_incorrect',
                            'median_response_time_overall',
                            'median_response_time_correct',
                            'median_response_time_incorrect',
                            'sd_response_time_overall',
                            'sd_response_time_correct',
                            'sd_response_time_incorrect'
                            ])

def summary_grid_memory(x, trials_expected=4):
    d = {}
    d['flag_is_invalid_n_trials'] = x['session_uuid'].count() != trials_expected
    d['n_trials'] = x['session_uuid'].count()
    # d['n_trials_responsetime_lt250ms'] = (
    #     x['response_time_duration_ms'] < 250).sum()
    # d['n_trials_responsetime_gt10000ms'] = (
    #     x['response_time_duration_ms'] > 10000).sum()
    d['n_perfect_trials'] = (x['number_of_correct_dots'] == 3.0).sum()
    #d['n_user_interference_actions'] = len(json.loads(x['user_interference_actions'].values[0]))
    d['mean_correct_dots'] = (x['number_of_correct_dots']).mean()
    d['min_correct_dots'] = (x['number_of_correct_dots']).min()
    d['sum_correct_dots'] = (x['number_of_correct_dots']).sum()
    #d['mean_response_time_overall'] = x['response_time_duration_ms'].mean()
    # d['mean_response_time_correct'] = x.loc[(x['user_response_index']
    #                                          == x['correct_response_index']), 'response_time_duration_ms'].mean()
    #d['median_response_time_overall'] = x['response_time_duration_ms'].median()
    #d['sd_response_time_overall'] = x['response_time_duration_ms'].std()
    return pd.Series(d,
                     index=['flag_is_invalid_n_trials',
                            # 'flag_is_potentially_invalid_rt',
                            'n_trials',
                            # 'n_trials_responsetime_lt250ms',
                            # 'n_trials_responsetime_gt10000ms',
                            'n_perfect_trials',
                            # 'n_user_interference_actions',
                            'mean_correct_dots',
                            'min_correct_dots',
                            'sum_correct_dots',
                            # 'mean_response_time_overall',
                            # 'median_response_time_overall',
                            # 'sd_response_time_overall',
                            ])

# %%
import pandas as pd

#https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20List.html
data_files = glob.glob('data/*.json')
file_to_process = widgets.Dropdown(
    options=data_files,
    layout={'width': 'max-content'},
    value=(data_files[0]),
    description='File to convert:',
)
display(file_to_process)
# Out:
# Dropdown(description='File to convert:', layout=Layout(width='max-content'), options=('data/2023-01-20_05-56-3…

# %%
# constants
fn_split_delim = "-data_study-" # delimiter for splitting filename

# generate job timestamp and uuid
job_uuid = str(uuid.uuid4())
job_ts = time.strftime("%Y%m%d-%H%M%S")

# load data from exporter S3 bucket
fn = file_to_process.value
all_records = json.load(open(fn))

# extract study_uid from filename
study_uid = fn.split(fn_split_delim)[1].split(".")[0] # the thing right after the split delimiter
print(f"Processing study: {study_uid} | {fn}")

# extract 'trials' from records object
all_trials = extract_all_trials(all_records, format="pandas")
display(all_trials)

raw_csv_file = f"tidy/{job_ts}_m2c2kit_exporter-raw-data_uuid-{job_uuid}_study-{study_uid}.csv"

# save to csv
all_trials.to_csv(raw_csv_file, index=False)

df = pd.read_csv(raw_csv_file)
df.columns
display(df.head(3))

# number of sessions per activity
df.groupby("activity_id")["session_uuid"].count()

# number of api_keys = should be 1 per study
df.groupby("api_key")["api_key"].count()

for activity, frame in df.groupby("activity_id"):
    print(f"Processing activity: {activity}")
    print("-------------------------")
    frame_ = frame.drop_duplicates()
    frame_.columns
    csv_file_act = f"tidy/{job_ts}_m2c2kit_exporter-summary-data_activity-{activity}_uuid-{job_uuid}_study-{study_uid}.csv"
    if(activity == "symbol-search"):
        summary_df = frame_.groupby(["participant_id", "session_uuid", "session_id"]).apply(summary_symbol_search)
        summary_df.reset_index().to_csv(csv_file_act, index=False)
        display(summary_df)
    else:
        summary_df = frame_.groupby(["participant_id", "session_uuid", "session_id"]).apply(summary_grid_memory)
        summary_df.reset_index().to_csv(csv_file_act, index=False)
    display(summary_df)
# Out:
# data/2023-01-20_05-55-51-db-m2c2api_collection-data_study-MOTLAB.json
# Processing study: MOTLAB
#                                 session_uuid  \
# 0       7bdb246e-bbf9-4a0a-8b54-0026336cb5ee
# 1       7bdb246e-bbf9-4a0a-8b54-0026336cb5ee
# 2       7bdb246e-bbf9-4a0a-8b54-0026336cb5ee
# 3       7bdb246e-bbf9-4a0a-8b54-0026336cb5ee
# 4       7bdb246e-bbf9-4a0a-8b54-0026336cb5ee
# ...                                      ...
# 572931  b18d52f8-aa95-44e6-b550-7df7860fd14f
# 572932  b18d52f8-aa95-44e6-b550-7df7860fd14f
# 572933  b18d52f8-aa95-44e6-b550-7df7860fd14f
# 572934  b18d52f8-aa95-44e6-b550-7df7860fd14f
# 572935  b18d52f8-aa95-44e6-b550-7df7860fd14f
#
#                                activity_uuid  activity_id activity_version  \
# 0       e9ba8871-3395-4f83-ba01-78136160a914  grid-memory            0.8.1
# 1       e9ba8871-3395-4f83-ba01-78136160a914  grid-memory            0.8.1
# 2       e9ba8871-3395-4f83-ba01-78136160a914  grid-memory            0.8.1
# 3       e9ba8871-3395-4f83-ba01-78136160a914  grid-memory            0.8.1
# 4       e9ba8871-3395-4f83-ba01-78136160a914  grid-memory            0.8.1
# ...                                      ...          ...              ...
# 572931  6b707cdb-2edc-48e3-9d28-916e57c3c551  grid-memory            0.8.1
# 572932  6b707cdb-2edc-48e3-9d28-916e57c3c551  grid-memory            0.8.1
# 572933  6b707cdb-2edc-48e3-9d28-916e57c3c551  grid-memory            0.8.1
# 572934  6b707cdb-2edc-48e3-9d28-916e57c3c551  grid-memory            0.8.1
# 572935  6b707cdb-2edc-48e3-9d28-916e57c3c551  grid-memory            0.8.1
#
#        activity_begin_iso8601_timestamp trial_begin_iso8601_timestamp  \
# 0              2023-01-15T18:23:25.139Z      2023-01-15T18:23:52.964Z
# 1              2023-01-15T18:23:25.139Z      2023-01-15T18:24:11.374Z
# 2              2023-01-15T18:23:25.139Z      2023-01-15T18:24:32.481Z
# 3              2023-01-15T18:23:25.139Z      2023-01-15T18:24:51.722Z
# 4              2023-01-15T18:23:25.139Z      2023-01-15T18:23:52.964Z
# ...                                 ...                           ...
# 572931         2022-12-16T15:30:29.946Z      2022-12-16T15:30:41.267Z
# 572932         2022-12-16T15:30:29.946Z      2022-12-16T15:31:00.247Z
# 572933         2022-12-16T15:30:29.946Z      2022-12-16T15:30:41.267Z
# 572934         2022-12-16T15:30:29.946Z      2022-12-16T15:31:00.247Z
# 572935         2022-12-16T15:30:29.946Z      2022-12-16T15:31:20.026Z
#
#         trial_index                                    presented_cells  \
# 0                 0  [{'row': 2, 'column': 3}, {'row': 1, 'column':...
# 1                 1  [{'row': 1, 'column': 3}, {'row': 0, 'column':...
# 2                 2  [{'row': 0, 'column': 4}, {'row': 0, 'column':...
# 3                 3  [{'row': 4, 'column': 2}, {'row': 1, 'column':...
# 4                 0  [{'row': 2, 'column': 3}, {'row': 1, 'column':...
# ...             ...                                                ...
# 572931            0  [{'row': 3, 'column': 1}, {'row': 0, 'column':...
# 572932            1  [{'row': 4, 'column': 0}, {'row': 0, 'column':...
# 572933            0  [{'row': 3, 'column': 1}, {'row': 0, 'column':...
# 572934            1  [{'row': 4, 'column': 0}, {'row': 0, 'column':...
# 572935            2  [{'row': 4, 'column': 2}, {'row': 1, 'column':...
#
#                                            selected_cells  \
# 0       [{'row': 1, 'column': 0}, {'row': 3, 'column':...
# 1       [{'row': 3, 'column': 4}, {'row': 2, 'column':...
# 2       [{'row': 0, 'column': 4}, {'row': 1, 'column':...
# 3       [{'row': 0, 'column': 3}, {'row': 1, 'column':...
# 4       [{'row': 1, 'column': 0}, {'row': 3, 'column':...
# ...                                                   ...
# 572931  [{'row': 4, 'column': 1}, {'row': 2, 'column':...
# 572932  [{'row': 0, 'column': 0}, {'row': 4, 'column':...
# 572933  [{'row': 4, 'column': 1}, {'row': 2, 'column':...
# 572934  [{'row': 0, 'column': 0}, {'row': 4, 'column':...
# 572935  [{'row': 2, 'column': 0}, {'row': 4, 'column':...
#
#                                          user_dot_actions  ...  \
# 0       [{'elapsed_duration_ms': 2193.199999988079, 'a...  ...
# 1       [{'elapsed_duration_ms': 6042.300000011921, 'a...  ...
# 2       [{'elapsed_duration_ms': 1389.5, 'action_type'...  ...
# 3       [{'elapsed_duration_ms': 2340.800000011921, 'a...  ...
# 4       [{'elapsed_duration_ms': 2193.199999988079, 'a...  ...
# ...                                                   ...  ...
# 572931  [{'elapsed_duration_ms': 1882.7999999821186, '...  ...
# 572932  [{'elapsed_duration_ms': 2172.199999988079, 'a...  ...
# 572933  [{'elapsed_duration_ms': 1882.7999999821186, '...  ...
# 572934  [{'elapsed_duration_ms': 2172.199999988079, 'a...  ...
# 572935  [{'elapsed_duration_ms': 3729.7000000178814, '...  ...
#
#                                           device_metadata  session_id  \
# 0       {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2
# 1       {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2
# 2       {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2
# 3       {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2
# 4       {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2
# ...                                                   ...         ...
# 572931  {'userAgent': 'Mozilla/5.0 (Linux; Android 12;...           2
# 572932  {'userAgent': 'Mozilla/5.0 (Linux; Android 12;...           2
# 572933  {'userAgent': 'Mozilla/5.0 (Linux; Android 12;...           2
# 572934  {'userAgent': 'Mozilla/5.0 (Linux; Android 12;...           2
# 572935  {'userAgent': 'Mozilla/5.0 (Linux; Android 12;...           2
#
#         study_id participant_id                               api_key  \
# 0         MOTLAB          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 1         MOTLAB          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 2         MOTLAB          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 3         MOTLAB          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 4         MOTLAB          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# ...          ...            ...                                   ...
# 572931    MOTLAB          82061  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 572932    MOTLAB          82061  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 572933    MOTLAB          82061  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 572934    MOTLAB          82061  e482b3a1-3b71-4883-a4c2-6efab9db69c6
# 572935    MOTLAB          82061  e482b3a1-3b71-4883-a4c2-6efab9db69c6
#
#        trial_type card_configuration response_time_duration_ms  \
# 0             NaN                NaN                       NaN
# 1             NaN                NaN                       NaN
# 2             NaN                NaN                       NaN
# 3             NaN                NaN                       NaN
# 4             NaN                NaN                       NaN
# ...           ...                ...                       ...
# 572931        NaN                NaN                       NaN
# 572932        NaN                NaN                       NaN
# 572933        NaN                NaN                       NaN
# 572934        NaN                NaN                       NaN
# 572935        NaN                NaN                       NaN
#
#        user_response_index correct_response_index
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      NaN                    NaN
# 4                      NaN                    NaN
# ...                    ...                    ...
# 572931                 NaN                    NaN
# 572932                 NaN                    NaN
# 572933                 NaN                    NaN
# 572934                 NaN                    NaN
# 572935                 NaN                    NaN
#
# [572936 rows x 23 columns]
# /Users/nelsonroque/.pyenv/versions/3.7.10/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                            session_uuid                         activity_uuid  \
# 0  7bdb246e-bbf9-4a0a-8b54-0026336cb5ee  e9ba8871-3395-4f83-ba01-78136160a914
# 1  7bdb246e-bbf9-4a0a-8b54-0026336cb5ee  e9ba8871-3395-4f83-ba01-78136160a914
# 2  7bdb246e-bbf9-4a0a-8b54-0026336cb5ee  e9ba8871-3395-4f83-ba01-78136160a914
#
#    activity_id activity_version activity_begin_iso8601_timestamp  \
# 0  grid-memory            0.8.1         2023-01-15T18:23:25.139Z
# 1  grid-memory            0.8.1         2023-01-15T18:23:25.139Z
# 2  grid-memory            0.8.1         2023-01-15T18:23:25.139Z
#
#   trial_begin_iso8601_timestamp  trial_index  \
# 0      2023-01-15T18:23:52.964Z            0
# 1      2023-01-15T18:24:11.374Z            1
# 2      2023-01-15T18:24:32.481Z            2
#
#                                      presented_cells  \
# 0  [{'row': 2, 'column': 3}, {'row': 1, 'column':...
# 1  [{'row': 1, 'column': 3}, {'row': 0, 'column':...
# 2  [{'row': 0, 'column': 4}, {'row': 0, 'column':...
#
#                                       selected_cells  \
# 0  [{'row': 1, 'column': 0}, {'row': 3, 'column':...
# 1  [{'row': 3, 'column': 4}, {'row': 2, 'column':...
# 2  [{'row': 0, 'column': 4}, {'row': 1, 'column':...
#
#                                     user_dot_actions  ...  \
# 0  [{'elapsed_duration_ms': 2193.199999988079, 'a...  ...
# 1  [{'elapsed_duration_ms': 6042.300000011921, 'a...  ...
# 2  [{'elapsed_duration_ms': 1389.5, 'action_type'...  ...
#
#                                      device_metadata  session_id  study_id  \
# 0  {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2    MOTLAB
# 1  {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2    MOTLAB
# 2  {'userAgent': 'Mozilla/5.0 (Windows NT 10.0; W...           2    MOTLAB
#
#   participant_id                               api_key trial_type  \
# 0          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6        NaN
# 1          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6        NaN
# 2          85874  e482b3a1-3b71-4883-a4c2-6efab9db69c6        NaN
#
#   card_configuration response_time_duration_ms user_response_index  \
# 0                NaN                       NaN                 NaN
# 1                NaN                       NaN                 NaN
# 2                NaN                       NaN                 NaN
#
#   correct_response_index
# 0                    NaN
# 1                    NaN
# 2                    NaN
#
# [3 rows x 23 columns]
# Processing activity: grid-memory
# -------------------------
#                                                                 flag_is_invalid_n_trials  \
# participant_id session_uuid                         session_id
# 1025           89d0639e-75de-4b23-8a73-105e47608e52 2                              False
#                b214346e-66ce-4474-a413-9bd5ec992ec3 1                              False
# 1053           87aafffd-97d7-4510-99b5-a3ae0de45e69 1                              False
#                d9b9baaf-3416-4677-a3e1-b421c8220c53 2                              False
# 1059           3d621016-fe1c-4b3c-8858-7e2a7cf550a1 2                              False
# ...                                                                                  ...
# QUALTRICSID    69611119-0775-4984-be4c-0f82a2984495 ANUMBER                        False
#                796952b7-b967-4bf2-b778-14baec6e3382 ANUMBER                        False
#                ae12f15f-b1fd-4eca-9f20-b938e3509745 ANUMBER                        False
#                bb8fdcc8-5735-42e8-a136-762f4407a6a5 ANUMBER                         True
#                f60bb472-4afc-4903-836c-f8eacc686631 ANUMBER                        False
#
#                                                                 n_trials  \
# participant_id session_uuid                         session_id
# 1025           89d0639e-75de-4b23-8a73-105e47608e52 2                  4
#                b214346e-66ce-4474-a413-9bd5ec992ec3 1                  4
# 1053           87aafffd-97d7-4510-99b5-a3ae0de45e69 1                  4
#                d9b9baaf-3416-4677-a3e1-b421c8220c53 2                  4
# 1059           3d621016-fe1c-4b3c-8858-7e2a7cf550a1 2                  4
# ...                                                                  ...
# QUALTRICSID    69611119-0775-4984-be4c-0f82a2984495 ANUMBER            4
#                796952b7-b967-4bf2-b778-14baec6e3382 ANUMBER            4
#                ae12f15f-b1fd-4eca-9f20-b938e3509745 ANUMBER            4
#                bb8fdcc8-5735-42e8-a136-762f4407a6a5 ANUMBER            2
#                f60bb472-4afc-4903-836c-f8eacc686631 ANUMBER            4
#
#                                                                 n_perfect_trials  \
# participant_id session_uuid                         session_id
# 1025           89d0639e-75de-4b23-8a73-105e47608e52 2                          0
#                b214346e-66ce-4474-a413-9bd5ec992ec3 1                          1
# 1053           87aafffd-97d7-4510-99b5-a3ae0de45e69 1                          0
#                d9b9baaf-3416-4677-a3e1-b421c8220c53 2                          2
# 1059           3d621016-fe1c-4b3c-8858-7e2a7cf550a1 2                          0
# ...                                                                          ...
# QUALTRICSID    69611119-0775-4984-be4c-0f82a2984495 ANUMBER                    3
#                796952b7-b967-4bf2-b778-14baec6e3382 ANUMBER                    3
#                ae12f15f-b1fd-4eca-9f20-b938e3509745 ANUMBER                    1
#                bb8fdcc8-5735-42e8-a136-762f4407a6a5 ANUMBER                    0
#                f60bb472-4afc-4903-836c-f8eacc686631 ANUMBER                    1
#
#                                                                 mean_correct_dots  \
# participant_id session_uuid                         session_id
# 1025           89d0639e-75de-4b23-8a73-105e47608e52 2                        0.75
#                b214346e-66ce-4474-a413-9bd5ec992ec3 1                        1.00
# 1053           87aafffd-97d7-4510-99b5-a3ae0de45e69 1                        0.75
#                d9b9baaf-3416-4677-a3e1-b421c8220c53 2                        1.50
# 1059           3d621016-fe1c-4b3c-8858-7e2a7cf550a1 2                        1.50
# ...                                                                           ...
# QUALTRICSID    69611119-0775-4984-be4c-0f82a2984495 ANUMBER                  2.75
#                796952b7-b967-4bf2-b778-14baec6e3382 ANUMBER                  2.75
#                ae12f15f-b1fd-4eca-9f20-b938e3509745 ANUMBER                  1.50
#                bb8fdcc8-5735-42e8-a136-762f4407a6a5 ANUMBER                  0.00
#                f60bb472-4afc-4903-836c-f8eacc686631 ANUMBER                  1.75
#
#                                                                 min_correct_dots  \
# participant_id session_uuid                         session_id
# 1025           89d0639e-75de-4b23-8a73-105e47608e52 2                        0.0
#                b214346e-66ce-4474-a413-9bd5ec992ec3 1                        0.0
# 1053           87aafffd-97d7-4510-99b5-a3ae0de45e69 1                        0.0
#                d9b9baaf-3416-4677-a3e1-b421c8220c53 2                        0.0
# 1059           3d621016-fe1c-4b3c-8858-7e2a7cf550a1 2                        0.0
# ...                                                                          ...
# QUALTRICSID    69611119-0775-4984-be4c-0f82a2984495 ANUMBER                  2.0
#                796952b7-b967-4bf2-b778-14baec6e3382 ANUMBER                  2.0
#                ae12f15f-b1fd-4eca-9f20-b938e3509745 ANUMBER                  1.0
#                bb8fdcc8-5735-42e8-a136-762f4407a6a5 ANUMBER                  0.0
#                f60bb472-4afc-4903-836c-f8eacc686631 ANUMBER                  1.0
#
#                                                                 sum_correct_dots
# participant_id session_uuid                         session_id
# 1025           89d0639e-75de-4b23-8a73-105e47608e52 2                        3.0
#                b214346e-66ce-4474-a413-9bd5ec992ec3 1                        4.0
# 1053           87aafffd-97d7-4510-99b5-a3ae0de45e69 1                        3.0
#                d9b9baaf-3416-4677-a3e1-b421c8220c53 2                        6.0
# 1059           3d621016-fe1c-4b3c-8858-7e2a7cf550a1 2                        6.0
# ...                                                                          ...
# QUALTRICSID    69611119-0775-4984-be4c-0f82a2984495 ANUMBER                 11.0
#                796952b7-b967-4bf2-b778-14baec6e3382 ANUMBER                 11.0
#                ae12f15f-b1fd-4eca-9f20-b938e3509745 ANUMBER                  6.0
#                bb8fdcc8-5735-42e8-a136-762f4407a6a5 ANUMBER                  0.0
#                f60bb472-4afc-4903-836c-f8eacc686631 ANUMBER                  7.0
#
# [2537 rows x 6 columns]
# Processing activity: symbol-search
# -------------------------
#                                                                 flag_is_invalid_n_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                              False
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                              False
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                              False
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                               True
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                              False
# ...                                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                        False
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                        False
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                        False
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                        False
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                         True
#
#                                                                 n_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                 20
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                 20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                 20
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                 19
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                 20
# ...                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER           20
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER           20
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER           20
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER           20
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER            1
#
#                                                                 n_trials_lure  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                      10
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                      10
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                      10
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                       9
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                      10
# ...                                                                       ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                10
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                10
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                10
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                10
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                 1
#
#                                                                 n_correct_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                         20
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                         20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                         18
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                         17
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                         18
# ...                                                                          ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                   19
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                   20
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                   20
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                   20
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                    1
#
#                                                                 n_incorrect_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                            0
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                            0
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                            2
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                            2
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                            2
# ...                                                                            ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                      1
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                      0
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                      0
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                      0
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                      0
#
#                                                                 n_trials_responsetime_lt250ms  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                       0
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                       0
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                       0
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                       0
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                       0
# ...                                                                                       ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                                 0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                                 0
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                                 0
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                                 0
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                                 0
#
#                                                                 n_trials_responsetime_gt10000ms  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                         0
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                         0
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                         1
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                         0
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                         0
# ...                                                                                         ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                                   0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                                   0
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                                   0
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                                   0
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                                   0
#
#                                                                 mean_response_time_overall  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                          3649.530000
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                          2749.595000
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                          3931.215000
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                          3079.515789
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                          2476.200000
# ...                                                                                    ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                    2052.300000
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                    1435.660000
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                    1665.600000
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                    1772.985000
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                    1578.000000
#
#                                                                 mean_response_time_correct  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                          3649.530000
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                          2749.595000
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                          4079.127778
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                          3082.682353
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                          2510.833333
# ...                                                                                    ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                    2021.000000
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                    1435.660000
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                    1665.600000
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                    1772.985000
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                    1578.000000
#
#                                                                 mean_response_time_incorrect  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                    NaN
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                    NaN
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                 2600.0
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                 3052.6
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                 2164.5
# ...                                                                                      ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                           2647.0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                              NaN
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                              NaN
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                              NaN
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                              NaN
#
#                                                                 median_response_time_overall  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                3451.95
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                2670.20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                3529.95
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                2744.20
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                2541.00
# ...                                                                                      ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                          2020.50
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                          1476.35
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                          1573.50
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                          1729.05
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          1578.00
#
#                                                                 median_response_time_correct  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                3451.95
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                2670.20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                3587.15
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                2744.20
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                2541.00
# ...                                                                                      ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                          1979.00
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                          1476.35
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                          1573.50
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                          1729.05
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          1578.00
#
#                                                                 median_response_time_incorrect  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                      NaN
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                      NaN
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                   2600.0
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                   3052.6
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                   2164.5
# ...                                                                                        ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                             2647.0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                                NaN
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                                NaN
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                                NaN
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                                NaN
#
#                                                                 sd_response_time_overall  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                        1323.363184
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                        1049.342706
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                        2909.743480
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                        1265.744149
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                         774.904042
# ...                                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                   576.660906
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                   400.147388
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                   427.945816
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                   438.338842
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          NaN
#
#                                                                 sd_response_time_correct  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                        1323.363184
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                        1049.342706
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                        3022.847729
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                        1260.995476
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                         796.045391
# ...                                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                   574.743228
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                   400.147388
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                   427.945816
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                   438.338842
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          NaN
#
#                                                                 sd_response_time_incorrect
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                  NaN
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                  NaN
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                          1260.205705
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                          1842.437429
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                           648.416918
# ...                                                                                    ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                            NaN
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                            NaN
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                            NaN
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                            NaN
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                            NaN
#
# [2689 rows x 16 columns]
#                                                                 flag_is_invalid_n_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                              False
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                              False
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                              False
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                               True
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                              False
# ...                                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                        False
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                        False
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                        False
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                        False
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                         True
#
#                                                                 n_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                 20
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                 20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                 20
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                 19
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                 20
# ...                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER           20
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER           20
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER           20
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER           20
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER            1
#
#                                                                 n_trials_lure  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                      10
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                      10
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                      10
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                       9
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                      10
# ...                                                                       ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                10
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                10
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                10
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                10
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                 1
#
#                                                                 n_correct_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                         20
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                         20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                         18
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                         17
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                         18
# ...                                                                          ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                   19
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                   20
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                   20
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                   20
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                    1
#
#                                                                 n_incorrect_trials  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                            0
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                            0
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                            2
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                            2
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                            2
# ...                                                                            ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                      1
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                      0
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                      0
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                      0
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                      0
#
#                                                                 n_trials_responsetime_lt250ms  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                       0
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                       0
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                       0
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                       0
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                       0
# ...                                                                                       ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                                 0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                                 0
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                                 0
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                                 0
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                                 0
#
#                                                                 n_trials_responsetime_gt10000ms  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                         0
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                         0
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                         1
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                         0
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                         0
# ...                                                                                         ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                                   0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                                   0
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                                   0
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                                   0
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                                   0
#
#                                                                 mean_response_time_overall  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                          3649.530000
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                          2749.595000
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                          3931.215000
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                          3079.515789
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                          2476.200000
# ...                                                                                    ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                    2052.300000
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                    1435.660000
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                    1665.600000
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                    1772.985000
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                    1578.000000
#
#                                                                 mean_response_time_correct  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                          3649.530000
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                          2749.595000
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                          4079.127778
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                          3082.682353
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                          2510.833333
# ...                                                                                    ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                    2021.000000
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                    1435.660000
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                    1665.600000
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                    1772.985000
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                    1578.000000
#
#                                                                 mean_response_time_incorrect  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                    NaN
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                    NaN
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                 2600.0
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                 3052.6
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                 2164.5
# ...                                                                                      ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                           2647.0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                              NaN
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                              NaN
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                              NaN
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                              NaN
#
#                                                                 median_response_time_overall  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                3451.95
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                2670.20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                3529.95
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                2744.20
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                2541.00
# ...                                                                                      ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                          2020.50
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                          1476.35
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                          1573.50
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                          1729.05
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          1578.00
#
#                                                                 median_response_time_correct  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                3451.95
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                2670.20
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                3587.15
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                2744.20
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                2541.00
# ...                                                                                      ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                          1979.00
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                          1476.35
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                          1573.50
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                          1729.05
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          1578.00
#
#                                                                 median_response_time_incorrect  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                      NaN
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                      NaN
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                                   2600.0
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                                   3052.6
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                                   2164.5
# ...                                                                                        ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                             2647.0
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                                NaN
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                                NaN
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                                NaN
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                                NaN
#
#                                                                 sd_response_time_overall  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                        1323.363184
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                        1049.342706
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                        2909.743480
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                        1265.744149
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                         774.904042
# ...                                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                   576.660906
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                   400.147388
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                   427.945816
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                   438.338842
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          NaN
#
#                                                                 sd_response_time_correct  \
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                        1323.363184
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                        1049.342706
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                        3022.847729
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                        1260.995476
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                         796.045391
# ...                                                                                  ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                   574.743228
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                   400.147388
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                   427.945816
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                   438.338842
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                          NaN
#
#                                                                 sd_response_time_incorrect
# participant_id session_uuid                         session_id
# 1025           2592d493-61b2-4129-97d7-90b373fbb9f2 1                                  NaN
#                39fceb35-b433-49d0-acb2-b0a4801be038 2                                  NaN
# 1053           1ff76f21-9cf5-4d20-aaf5-01a7b6acb2c4 2                          1260.205705
#                5d2029a7-4a30-44ac-9e3f-54d0deb3ebe8 1                          1842.437429
# 1059           3c80fb20-b91d-492b-9549-7a2de3718bcf 1                           648.416918
# ...                                                                                    ...
# QUALTRICSID    a26a9de9-b8ae-4326-8442-6de0272f6392 ANUMBER                            NaN
#                c4362e29-5107-42c9-9eee-a1986286b85f ANUMBER                            NaN
#                d38fd29f-055b-4ffb-8937-65a95e3e864f ANUMBER                            NaN
#                da915955-a948-4f6f-80ea-ffd8dc3c7a41 ANUMBER                            NaN
#                fbbd78fa-878f-4cf4-8fdd-51425c8055f0 ANUMBER                            NaN
#
# [2689 rows x 16 columns]
